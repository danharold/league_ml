# %%
from riot_request.request import RiotRequest

api_key = "RGAPI-94402067-bb26-4a4c-b517-216bd4d50a4f"
riot = RiotRequest(api_key, "Incident", "euw1")

# %%
my_puuid = riot.me['puuid']

chal = riot.get_challenger_players()
gm = riot.get_grandmaster_players()

# %%
gm
# Out:
# {'tier': 'GRANDMASTER',
#  'leagueId': '42e89ab6-c756-30c9-b4d7-792b223a6bba',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Draven's Rageborn",
#  'entries': [{'summonerId': 'r9IIYNCIHms6l-cNld3ovS0nRr_I7HcgJHKLYi3BNo4rS6vjPdVaovyY7A',
#    'summonerName': 'Crisp trainee',
#    'leaguePoints': 691,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BWiwFZEEFGr0XfmuEuOEObHgpU82L9csq0RicbRoCUeY_4o',
#    'summonerName': 'myrwn test acc',
#    'leaguePoints': 620,
#    'rank': 'I',
#    'wins': 406,
#    'losses': 376,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'yvozdBKLjB9cKjcJOgrC3BZ_wOdacpBAQuaOeJHdRp70YmE2',
#    'summonerName': 'Kæmpe Røv',
#    'leaguePoints': 753,
#    'rank': 'I',
#    'wins': 152,
#    'losses': 106,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1OSMPXWlfOB_kb_aI_DBw04UC-ov7t8Sa51IUdRfo522oOmUA_5oBmJYew',
#    'summonerName': 'god13589743219',
#    'leaguePoints': 633,
#    'rank': 'I',
#    'wins': 196,
#    'losses': 189,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nMGBRMRCZR5iKnZBdzDI7MHTgdrmLJuMQQV4MIXAX1qj4uh7',
#    'summonerName': 'Hyweedri',
#    'leaguePoints': 729,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 107,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'J7G9GLsEKLr4iFZ0A2qu5oUfvbT_H8r4r6CLv68e4xTyvpZU',
#    'summonerName': 'Weakside Rebel',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'llrbEZUuh48gbA-uUZ05PcvCPvetQAn6Rqp_juoeGHZQnh8',
#    'summonerName': 'finnry',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nDzQZviXSqpCW84Ry0L8O0TFX-sjdzR2R0dtlek5V4ETpVSx',
#    'summonerName': 'Sherith',
#    'leaguePoints': 620,
#    'rank': 'I',
#    'wins': 191,
#    'losses': 158,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OL67m7ph4ccclgbHAj0o-RilgqYp7XUyczAJFpKeRGTx4hk',
#    'summonerName': 'qeqr',
#    'leaguePoints': 736,
#    'rank': 'I',
#    'wins': 303,
#    'losses': 265,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_J-HohbxKhRAWI-1e_eNG0Q8hapE1z04P1-Y32Tz3j8cKFM',
#    'summonerName': 'THE CHREAK',
#    'leaguePoints': 795,
#    'rank': 'I',
#    'wins': 351,
#    'losses': 305,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zyWFllo0YVhVdHekNfcOSS_xd2KrSvnQoaPX2C7ocydr-6jf',
#    'summonerName': 'N0TRétaardeédTBH',
#    'leaguePoints': 679,
#    'rank': 'I',
#    'wins': 368,
#    'losses': 326,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'obUjNOXL_hAMuPy0gf4FZIHMItoH48-BBIJf-A9dGEmtB1A',
#    'summonerName': 'ATN Guarding You',
#    'leaguePoints': 641,
#    'rank': 'I',
#    'wins': 239,
#    'losses': 212,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'pgrqdHcGIiXmXMc2usSKg2ZcdMAlAY2fSwad9fKaf4cla_M',
#    'summonerName': 'Same oId story ',
#    'leaguePoints': 765,
#    'rank': 'I',
#    'wins': 361,
#    'losses': 328,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tLa-14EFCJIYcWFh9jVuT3CeNjKtdxKyffZFhxuV6n7bAao',
#    'summonerName': 'The egion',
#    'leaguePoints': 674,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 69,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'yjM1seHwHB03WsW6Fy654X7ujRYQabNvgnZoHJnh7-PaVRc',
#    'summonerName': 'Lord Dinger',
#    'leaguePoints': 865,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'C4HNGf_wZVbO0-Y1aER0iaoBerQfk_HnVsMr0YcQcqO-108',
#    'summonerName': 'Lumerion',
#    'leaguePoints': 786,
#    'rank': 'I',
#    'wins': 612,
#    'losses': 566,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'o2_0XUrTKHoShke94DVB5Opq1LfK98vxDn-Lv-dluRvwJiRN',
#    'summonerName': 'Incognito Elec',
#    'leaguePoints': 669,
#    'rank': 'I',
#    'wins': 270,
#    'losses': 224,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'NGHHhw7JTHC41AoFQ4SUUj77gBIu3hSuvDsc0mrFk4yd9iM',
#    'summonerName': 'Gokkex',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 537,
#    'losses': 479,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'SGxj9UmU2G0GB49O9irenhvfE1jgDrUdWQJYoF2ydY1lmll7',
#    'summonerName': 'dhvs',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 240,
#    'losses': 219,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Iz7dq5f8M1U2Djh5v3i-AXf6vDCJnk4UEtLaFbJVSJTutDB_',
#    'summonerName': 'indimandi',
#    'leaguePoints': 876,
#    'rank': 'I',
#    'wins': 166,
#    'losses': 115,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'inUITftXXvdTIPFZBZ-QGc-DejtdZ09mX4EIB2U38au2i9YQ2AhJsbsaPA',
#    'summonerName': 'BZFCFCNBON',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 128,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'sKCfTKp61D0OK6wkwiSDmq4rsrVvApo3xJvpQdhYMwyCabk',
#    'summonerName': '4tukano4',
#    'leaguePoints': 636,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '8KfUu00kWlNuOA7MYaBg9uUuR3kTbJTPEaNljcE5GSIM47_8jEcg20DSkQ',
#    'summonerName': 'nothing to add',
#    'leaguePoints': 664,
#    'rank': 'I',
#    'wins': 475,
#    'losses': 446,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'aSi23bW0uB4hOYtiVZu6-WfUyzVVxJRhEeTIwBSRZrOVafrZjPebvPgwXA',
#    'summonerName': 'DV1 PolskiKoz',
#    'leaguePoints': 683,
#    'rank': 'I',
#    'wins': 281,
#    'losses': 262,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MeKURCYVxN4YrbZVDGaX0VFW252-QJBzKu2dgvLrZ3OQXzs',
#    'summonerName': 'Salaheddine',
#    'leaguePoints': 649,
#    'rank': 'I',
#    'wins': 348,
#    'losses': 301,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IBNocZlVxX6n8Aj4BRJbE-khNr1wKhBqxluuPoc02_ULvDOyjRadg0_FEw',
#    'summonerName': 'Prowlers Kayn',
#    'leaguePoints': 812,
#    'rank': 'I',
#    'wins': 105,
#    'losses': 88,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'su-kybjhks1kp5c1IO_tCQbDUsGQthtsHUdwqiDZVdH3Ex0',
#    'summonerName': 'Timon',
#    'leaguePoints': 603,
#    'rank': 'I',
#    'wins': 440,
#    'losses': 412,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '2yVCWL_wErZYqt8YDVCdTg0mfBb69QsT8xmdWKwKUYYB4T4',
#    'summonerName': 'blq',
#    'leaguePoints': 804,
#    'rank': 'I',
#    'wins': 71,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bfN508-EH3BLcXgdgsBxKAkbgdKHNqS7FASWhy8hpUh4eQI',
#    'summonerName': 'ZIOM Mouzyn',
#    'leaguePoints': 758,
#    'rank': 'I',
#    'wins': 352,
#    'losses': 310,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'L1MaRUniDmYqfRnpGzarKC5NGnOL0Xx_PD1IaEdmitOWbu8',
#    'summonerName': 'Szygenda',
#    'leaguePoints': 776,
#    'rank': 'I',
#    'wins': 112,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'T6b8shH4fVvthHJX_Poq_XiA1vzpfJ6Xq9MPj_Dq5uKC-M9P',
#    'summonerName': 'Adaś',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1FEmhROFuHqP4lVwWT_C6DvQT3WmzC27y07ZFN0_4j1E1Yzn0xZ7vI5gog',
#    'summonerName': 'just a teenager',
#    'leaguePoints': 771,
#    'rank': 'I',
#    'wins': 207,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'mFGj_Km3We81QkxMqUHQYmL0QjpkcNzYXceDwcB8UugepXmm2slNNRC4bQ',
#    'summonerName': 'Câsâ De Rêngârin',
#    'leaguePoints': 805,
#    'rank': 'I',
#    'wins': 195,
#    'losses': 161,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '6HxCcJv2lFNbQQdlQDbaERNvZJM6_kUucM321wJ7iPYsdS-z',
#    'summonerName': '424PHL',
#    'leaguePoints': 896,
#    'rank': 'I',
#    'wins': 232,
#    'losses': 200,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'aM-iEi2hhnf1RgJXcpVT8J4eAfIzwDFAJb2cLMHggnMjRxoT1C-RyNFVug',
#    'summonerName': 'AtilganBoy',
#    'leaguePoints': 696,
#    'rank': 'I',
#    'wins': 365,
#    'losses': 314,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'aTUW2Zj4QhI4REEIIFHAzVpGRbxYw2mfHzCmmUYTIQhT-GE',
#    'summonerName': 'ismaaa1',
#    'leaguePoints': 732,
#    'rank': 'I',
#    'wins': 218,
#    'losses': 185,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'FsZCrdDci7Q2_6ce2yIEwEt90zXW-yVCEICkpSkyiu8QhU4',
#    'summonerName': 'Nillee',
#    'leaguePoints': 930,
#    'rank': 'I',
#    'wins': 592,
#    'losses': 549,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nTOjSmmnIBxrquupmpMTwuDbm3uyqhQuPdadtaaqqt92fIxZmJThl5SRoQ',
#    'summonerName': 'WatchMyPuppets',
#    'leaguePoints': 854,
#    'rank': 'I',
#    'wins': 318,
#    'losses': 283,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'qynWbqVx-8MwVIDEJO9RI5SJZbtAArbK_TYuDPq6V-P6juU',
#    'summonerName': 'S10 l R1',
#    'leaguePoints': 823,
#    'rank': 'I',
#    'wins': 623,
#    'losses': 589,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'V3xwEE2AaHoe3YtsvloohzJ11WASIe3EpUg8EF9u_t-So752',
#    'summonerName': 'LeBron The Xuy',
#    'leaguePoints': 824,
#    'rank': 'I',
#    'wins': 128,
#    'losses': 87,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'vyGTrmZSYnD2PyXuv8ugacSKw6jd7HdSkJ_GO4lVrxtwwFE',
#    'summonerName': 'Rychly',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 175,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'y8QPC2wnjWMFFt8kFabVDROIxt96AlAYiUWctWw8DJrhlAI',
#    'summonerName': 'TOG Tayto',
#    'leaguePoints': 651,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 170,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wim8uCUPSrwjeLbLnj6U2W8CgIWJSCPnQnT72wh2qwqlXYE',
#    'summonerName': 'WD Mozart',
#    'leaguePoints': 785,
#    'rank': 'I',
#    'wins': 409,
#    'losses': 369,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Nos-YXH5cl5Bf0kCWEkdaNtGk-jsxCwQSpCfaDcuo2VYmlGC',
#    'summonerName': 'TWTVBioticZilean',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 391,
#    'losses': 357,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Phoc6e3QbBKXkWm01VeJ5vMtcls6iemKqhyQqYaoTrgv-OI',
#    'summonerName': 'Twtv Makkro0',
#    'leaguePoints': 696,
#    'rank': 'I',
#    'wins': 326,
#    'losses': 296,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rHs-s9-Ladz4iTueI7fznnSbLRoA8usqpviLZDeGp7T_CC4',
#    'summonerName': 'Calmsky',
#    'leaguePoints': 850,
#    'rank': 'I',
#    'wins': 227,
#    'losses': 186,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'nDWvaX15QqpvGCTsztM26Pa3APGbL-w-Sk4nRg4oZpSWydU',
#    'summonerName': 'Saku',
#    'leaguePoints': 738,
#    'rank': 'I',
#    'wins': 740,
#    'losses': 696,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'WeAgp42b4FDSpZ28iPmsRFYzaYW_Ahh6ovXQ-535fTfvlIZ8',
#    'summonerName': 'umidi46',
#    'leaguePoints': 660,
#    'rank': 'I',
#    'wins': 90,
#    'losses': 74,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'e9ww5E51I8ow3oZ_tHqiBZmmgDrY-YEi4RWo7qRBSZvjanI',
#    'summonerName': '0zymandias',
#    'leaguePoints': 890,
#    'rank': 'I',
#    'wins': 364,
#    'losses': 322,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'RxI5h2HWLk1csYYFiyv15OuKNBcWmOyj_YNIQzJ4TAHBpLk',
#    'summonerName': 'Kamiloo ',
#    'leaguePoints': 617,
#    'rank': 'I',
#    'wins': 256,
#    'losses': 210,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AvpSjmRB4GQeJaMNTXsZn5REo5mhjbPAxM9_PN1WYbkqqWI',
#    'summonerName': 'Nash2',
#    'leaguePoints': 826,
#    'rank': 'I',
#    'wins': 224,
#    'losses': 178,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'hf9O2-5MTpf3Q53gObjjTZquLDmn6fP2ioBvQfFpqmDRyjA',
#    'summonerName': 'Mr Bear Market',
#    'leaguePoints': 775,
#    'rank': 'I',
#    'wins': 215,
#    'losses': 179,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'WN18gfnppdacsr04SBRU0RIvmaYrvE6cdySk-qDK8Pl_vxKI',
#    'summonerName': 'Βraındead',
#    'leaguePoints': 432,
#    'rank': 'I',
#    'wins': 281,
#    'losses': 245,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'OtHwsjTNEEiTNXvEQLGrHG5AtvIBkpJeqkqj5w8JBtj2ezyh',
#    'summonerName': 'PARUS 2',
#    'leaguePoints': 699,
#    'rank': 'I',
#    'wins': 178,
#    'losses': 152,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TpqouGHkhW6BjtGUvgpbZcJrTAYXeFxAAqgDK0iUz4C3oegu',
#    'summonerName': 'Gilius2',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 285,
#    'losses': 264,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'yXrFywjk6EVK9r6XF_9mvXmuWnkcLa4Gb4Wm2o139X_rt0Q',
#    'summonerName': 'cospect',
#    'leaguePoints': 719,
#    'rank': 'I',
#    'wins': 110,
#    'losses': 75,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'UFkGicuMMb9Qmks9DRjFLeOvbHcwF3QqL5-c0K_n0ny0eQY',
#    'summonerName': 'Obi Hajime',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 277,
#    'losses': 249,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'LVj-EDR7bilITOQE5kDHFHyGJ4FJw_R7kqTlA3ibnpvXlr4',
#    'summonerName': 'Qert',
#    'leaguePoints': 649,
#    'rank': 'I',
#    'wins': 94,
#    'losses': 62,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QzzgXBfs1TlTqyLPZ_x-eMPBigZrFr3XBWAWwM_FiqMHyOA',
#    'summonerName': 'Mishing You',
#    'leaguePoints': 873,
#    'rank': 'I',
#    'wins': 202,
#    'losses': 162,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'eLQv-nclxN_4ML8KbmlitK6_UoDpBQ6LBlhVdelqptX3gAc',
#    'summonerName': 'roblox in head',
#    'leaguePoints': 877,
#    'rank': 'I',
#    'wins': 287,
#    'losses': 245,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2XnWYbhsykSiLpeJg2cl-UnnC4DzEPnyWlEZEt1Oa8xBoJM',
#    'summonerName': 'LDLC Eika',
#    'leaguePoints': 851,
#    'rank': 'I',
#    'wins': 240,
#    'losses': 206,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'SsmvLVKy7sAoAJ2QGgkyXSXvTl6Xeq_aKFkoY1AtqGjAhmk',
#    'summonerName': 'PCS ThomasShelby',
#    'leaguePoints': 691,
#    'rank': 'I',
#    'wins': 961,
#    'losses': 935,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'lUzKOZts8FqKBWzdkLe1BYif6_GN_nO7Sg1g9LNqIv_Be9E',
#    'summonerName': 'KHK TLamp',
#    'leaguePoints': 817,
#    'rank': 'I',
#    'wins': 268,
#    'losses': 225,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'sfxZEt5CZj5H_sCyRhmd1ZU9q6MyjALNMYSGraqfg4qspY_l',
#    'summonerName': 'pivo in head',
#    'leaguePoints': 584,
#    'rank': 'I',
#    'wins': 439,
#    'losses': 414,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ar12fMMDfFer2-o3FgSxgcZuHWmCxa6IUCH3bVrkYRHJ5l4',
#    'summonerName': 'NΕVERMIND',
#    'leaguePoints': 917,
#    'rank': 'I',
#    'wins': 355,
#    'losses': 289,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'epIHDOEvtOaGbhiBcdmsCifT4GIF8gdEG1rQR14DCzpp35_W',
#    'summonerName': 'Xian Yushen',
#    'leaguePoints': 709,
#    'rank': 'I',
#    'wins': 380,
#    'losses': 346,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-kMlS8touV2kCKhA3BHx4KU_HXpA3OQLM5OnjTbuoN_7SjM',
#    'summonerName': 'bluerzor',
#    'leaguePoints': 670,
#    'rank': 'I',
#    'wins': 219,
#    'losses': 195,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OAtg6AnhQhz2MA23p97dIDzJL_Sk7F9UJKxeLgkwIWASZ6E',
#    'summonerName': 'Destï',
#    'leaguePoints': 629,
#    'rank': 'I',
#    'wins': 284,
#    'losses': 258,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '7x_-heStpKulnYMYfUbBJeUiViDolsZqNnH7FlLVE8zAfXc',
#    'summonerName': 'Whiteakitout',
#    'leaguePoints': 841,
#    'rank': 'I',
#    'wins': 415,
#    'losses': 368,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'stb-BOhHz5FW7_1sUvBAyNkCblluPB7Hk8zxuAMCOz3l1Fw',
#    'summonerName': 'LaSimz',
#    'leaguePoints': 710,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 104,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-_9YZlM2N1G6Ian-yzRUUve90_6AuebjMjPIAMOuZ8T-Hi5lq-Arp3xbPQ',
#    'summonerName': 'januaryneverends',
#    'leaguePoints': 766,
#    'rank': 'I',
#    'wins': 398,
#    'losses': 364,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KJfDo9iTBbfmLA8sEP2qBryU4cZZLZLhx8ODxtTpY_fmIO_wA70AR7nxiw',
#    'summonerName': 'UNKN0WN5',
#    'leaguePoints': 752,
#    'rank': 'I',
#    'wins': 435,
#    'losses': 402,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'cPYBznG59yGUQNzjNIJGwhlgC1C7NrxIcCtEYaeRnDcyzUY',
#    'summonerName': 'HSG WHIP',
#    'leaguePoints': 764,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 134,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_2z6tHPNBQo060dHk_4avIH5u5z3rrhl6-05F-shj5Mp17w',
#    'summonerName': 'RXBXCXP',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 242,
#    'losses': 214,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '36zTvbSgKDE9AzChvu5_Nv2mHUsc3JpvRzYc-ZyCfRhguIE',
#    'summonerName': 'UnlookyPoopy',
#    'leaguePoints': 696,
#    'rank': 'I',
#    'wins': 414,
#    'losses': 384,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UZAQRKTVNHnXMxr2kjlTPqiznMDORhqJ2t-ihHs4wChvb0ke7scbohPHIQ',
#    'summonerName': 'smallDrangedTOP',
#    'leaguePoints': 677,
#    'rank': 'I',
#    'wins': 176,
#    'losses': 134,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'tTP5p22uy_eAOhoxco8wvUY12RVFqGgvnWK42M7fDcTbHQrlUn3HaBvnmQ',
#    'summonerName': 'obese16y',
#    'leaguePoints': 594,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 150,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'un50lNI594Z3N9lDp9RJOR3dQIjToGnMsZmHM2SanXVmlyg',
#    'summonerName': 'Aesenar',
#    'leaguePoints': 700,
#    'rank': 'I',
#    'wins': 398,
#    'losses': 372,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'tC2y3dhBqvpW2myts3WST5Xqy7ld_XO_dFUohe5yTSXaTEzpz_GlSC5Dfg',
#    'summonerName': 'Crrazy',
#    'leaguePoints': 671,
#    'rank': 'I',
#    'wins': 377,
#    'losses': 343,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IIbfPvxSAULebViUy_mgQrNxOgJvSy2XED6H33i6JrRdfCYR',
#    'summonerName': 'DEZT0N',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 514,
#    'losses': 481,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PBjnehZOwh6VwetxNHPXQOw2F_yJbhSLdhIAICUn1h94swU',
#    'summonerName': 'toplane rookie',
#    'leaguePoints': 653,
#    'rank': 'I',
#    'wins': 458,
#    'losses': 434,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ol84nLw_2IpZthmt825cNJDMhkWnAHsc91AagMdmPBANdNg',
#    'summonerName': 'Reinicke',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 164,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8OpcLdoVknRKPWi3tKiWLXDTG-kOTNPeIpVpDKy4i1E3Z0o',
#    'summonerName': 'Nice Guy Ben',
#    'leaguePoints': 645,
#    'rank': 'I',
#    'wins': 311,
#    'losses': 280,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'eBASg4UrmqniD-t2xAIkCFehS2OwGPrCIYkiLEpYQYYCdFkCI7wKEYrCbA',
#    'summonerName': 'BABO TOP',
#    'leaguePoints': 765,
#    'rank': 'I',
#    'wins': 124,
#    'losses': 84,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'qLGkahSDUXEY1DV03TLNyXFraEUBMvf-QdoB17k0FaHHEABh',
#    'summonerName': 'F1VTY',
#    'leaguePoints': 714,
#    'rank': 'I',
#    'wins': 400,
#    'losses': 360,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VbgImXI8lfk7J4BfKPOKGn4gsg89QKnYiA5Ty0H8AbMai2M',
#    'summonerName': 'VININE Rafe',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 153,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'B3phFQGAvYqjWdTc75CeJ9LHi9VWbZNV-E_5sYh89-BZcGo',
#    'summonerName': 'Lifestyle',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 254,
#    'losses': 219,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'OFeAFCqAfq9VGgEFqy_XMps1fzOrzuzQDnjbEnfEStqV9RbF-gnSm-5mLQ',
#    'summonerName': 'JNX XNJ',
#    'leaguePoints': 844,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 82,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'my9-KCOygF7wvtBmCtqo8zw8_gjo_uVYEwb8xrr7bPSLoz0',
#    'summonerName': 'DIV Xagog',
#    'leaguePoints': 806,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 101,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'm4kxck59dpFvDl1mFipX806H36DDkOXmPEsK-c7jd4CgqXM',
#    'summonerName': 'Sleepin all Day',
#    'leaguePoints': 610,
#    'rank': 'I',
#    'wins': 486,
#    'losses': 461,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'w2IlyW0ZXVQNU2yGsneeyySuSQAH_nTUehBldEIxudtKBpOZ',
#    'summonerName': 'Batuuu',
#    'leaguePoints': 625,
#    'rank': 'I',
#    'wins': 400,
#    'losses': 364,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'eFEQKekSOmBjBuHpV1efqeO38eFOCX4O3bNszpXVjrE6dpgJ6ufnEBZRHg',
#    'summonerName': 'Ducky x',
#    'leaguePoints': 759,
#    'rank': 'I',
#    'wins': 267,
#    'losses': 251,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nVz2oMrUB3AQbCMVe2zA23P_seI3w3SXYhhxT3XkwNNr1Ds',
#    'summonerName': 'gdgd jg acc',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 113,
#    'losses': 92,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '0FokalXOmibUwXGn44yM0iOTOALjfYSSYdb5taAQFdy1fto',
#    'summonerName': 'GENK Guertas',
#    'leaguePoints': 761,
#    'rank': 'I',
#    'wins': 400,
#    'losses': 368,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wKibk8xt74RApqbA29Hlhs57clqf1NuBfRNFbvXKN28BUWk',
#    'summonerName': 'Shinei nouzεn',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 615,
#    'losses': 578,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'wnC9XiRODyCCAC681dPIpUxAWtPnogvAHthr0bzPloGGFm6X',
#    'summonerName': 'warlock lvl 21',
#    'leaguePoints': 716,
#    'rank': 'I',
#    'wins': 345,
#    'losses': 318,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'cGrqwMzoL2XKoUR4ifa_0jUzpVu2lLvwqtm0bKb6xmcGpSQ',
#    'summonerName': 'fury of kerberos',
#    'leaguePoints': 696,
#    'rank': 'I',
#    'wins': 330,
#    'losses': 309,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'o_eOjjt4ue4V2Pr8bSGFXrXzS7oGkRvE8wnN33Jsy9OmKD4',
#    'summonerName': 'KE Custrha',
#    'leaguePoints': 713,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 224,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'VdGFV8rqLjmhe86E8PJ6dh2Yol0Yo3xayN5TBNvhQIJURy4jXY6cDZ-MDw',
#    'summonerName': 'BABO JUNGLE',
#    'leaguePoints': 747,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 115,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'hjFuW1_YxKMHVi1VjfrNCaU8ITMEu96kWiNgI7NgC5DFMDuBFPTY05_CLA',
#    'summonerName': 'Badlulu00',
#    'leaguePoints': 843,
#    'rank': 'I',
#    'wins': 317,
#    'losses': 278,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1902YgDKnzsSwqclnIjXWdHpXAlUDFYjVToLz1J-r5jWP_c',
#    'summonerName': 'Haenyeo',
#    'leaguePoints': 700,
#    'rank': 'I',
#    'wins': 290,
#    'losses': 251,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'dNvxsHHP5Y4r7Wt-mcQsAnf0_V6QqVpcHD41bL4tbyt1QVQ',
#    'summonerName': 'Jojonet',
#    'leaguePoints': 765,
#    'rank': 'I',
#    'wins': 334,
#    'losses': 298,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '51hz1WSizLpAWwg7aCQ3OR4-KHx8N1MAbG-S_qymdC6JhVD7LZeyvEsdFg',
#    'summonerName': 'the name is mine',
#    'leaguePoints': 736,
#    'rank': 'I',
#    'wins': 80,
#    'losses': 42,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'R5et74pwlGJOr1Z43pWlArT94AHyqwaA_f9AyMLOj0rNadI',
#    'summonerName': 'HøIyPhoenix',
#    'leaguePoints': 821,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 83,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fjKCeOfe-rhw8S8odSkjetbjWLWXEroeC-qt3LtwVWun2nI',
#    'summonerName': 'FattyP',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 150,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'iQgrokIYGaCtxnxJpKrWRVLGHk_RlY69sPSfOKsSm1zaM9g',
#    'summonerName': 'TwTv Odysseus131',
#    'leaguePoints': 831,
#    'rank': 'I',
#    'wins': 188,
#    'losses': 144,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '9D_l37MUG9oBxovgtscMayMiIYohQOwEj_bLLje9XBmrdrA',
#    'summonerName': 'FlyingHamster404',
#    'leaguePoints': 696,
#    'rank': 'I',
#    'wins': 177,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Tqc5hA4dYYW4-hCL0oPo9ussxEYnP6BMrzYGqDGzKnVjjVpA',
#    'summonerName': 'FakeRookie1',
#    'leaguePoints': 824,
#    'rank': 'I',
#    'wins': 233,
#    'losses': 225,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PJAzHsx3R-16sixkLn4-_pVF8r_TQ2ix2EGp4e4klKPiHLs',
#    'summonerName': 'daddy bardo',
#    'leaguePoints': 648,
#    'rank': 'I',
#    'wins': 174,
#    'losses': 143,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'mhZS_iFBnRdhlAV7D56MfNjPCQtJDiRgzKC9rQ7mSbBVTaR9',
#    'summonerName': 'Xenis',
#    'leaguePoints': 814,
#    'rank': 'I',
#    'wins': 289,
#    'losses': 253,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5-N3zueFFd-0G8ibBDT7tgdNYW38IRcyCK0DGO0ZiSonZB4o',
#    'summonerName': 'Soul Gambit',
#    'leaguePoints': 753,
#    'rank': 'I',
#    'wins': 311,
#    'losses': 272,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'JI64xFbXhC_YnioYiBgiD7qd_2qE_kj_ShCVeY5Ws8-K1uPA',
#    'summonerName': 'Blazen',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 326,
#    'losses': 296,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'R_VPoaAnRKzHfuwnBceqR5alF4utCiGtSj0nIQxvxAs1VN3O',
#    'summonerName': 'miss pleasure',
#    'leaguePoints': 544,
#    'rank': 'I',
#    'wins': 619,
#    'losses': 589,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'zwWyviyutplWMkCCfr8ty3NzrRC7AughuhiU18--G4XTbbg',
#    'summonerName': 'Kuro Tony',
#    'leaguePoints': 778,
#    'rank': 'I',
#    'wins': 187,
#    'losses': 155,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'IlnOev9buYc_jQumK3rJYXPu9WgoiXYYwOg70Kug2OKIe8kL',
#    'summonerName': ' Silixelf',
#    'leaguePoints': 648,
#    'rank': 'I',
#    'wins': 260,
#    'losses': 229,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'iQreN8tbtHo-P45ZaThAMGA1_5ryghU0OyXGfr478S6upXc',
#    'summonerName': 'BurgerMäker',
#    'leaguePoints': 739,
#    'rank': 'I',
#    'wins': 267,
#    'losses': 235,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pSeVmWiSrALjn5D6IgChzYV8F_zPwmdMHz3EIzVMC7C-KZta',
#    'summonerName': 'Lurox',
#    'leaguePoints': 763,
#    'rank': 'I',
#    'wins': 252,
#    'losses': 220,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ofeg3T4BbE57bR3ERUT79VBXJdLC9gKsw-jJWrNnyuQjhYA',
#    'summonerName': '2023MCDONALD',
#    'leaguePoints': 646,
#    'rank': 'I',
#    'wins': 237,
#    'losses': 210,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pRk_ITcnkSICEZDl8Wq9bzOrjwoQGJK_l2FYqifPYPW1IB8',
#    'summonerName': 'Curling Captain',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 618,
#    'losses': 588,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'e884HxDMCJZU_p1t7MmxoE12HB_nREuQYDs-pNMAR-6-oUM',
#    'summonerName': 'zzz resting time',
#    'leaguePoints': 702,
#    'rank': 'I',
#    'wins': 184,
#    'losses': 151,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'odgnNuJWbvgWyoyzAOdGv1xxSIyfqXSyutCB0VPzBePyBGs',
#    'summonerName': 'CR FisheR',
#    'leaguePoints': 662,
#    'rank': 'I',
#    'wins': 530,
#    'losses': 499,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Kgj0RDiH1YhttxCRnnSS9Jv8ZY-oEp6uM9AwUEfYT7vAOCo',
#    'summonerName': 'Gusuo',
#    'leaguePoints': 739,
#    'rank': 'I',
#    'wins': 482,
#    'losses': 446,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Q3YqRULTIFVf5yYtgnzl3b_Hhs5QcQB76Ulu6K31drYjyESPWYEFpjU9Tw',
#    'summonerName': 'DHSYFJGG',
#    'leaguePoints': 850,
#    'rank': 'I',
#    'wins': 309,
#    'losses': 262,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'l0rUfNp8ChIlzKA1tAIZUuioO8SWar420hzq7S1aEdL4C7o',
#    'summonerName': 'Facen',
#    'leaguePoints': 719,
#    'rank': 'I',
#    'wins': 265,
#    'losses': 233,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'AoTGam3jz_1_cuf09i28P58Oh4JPFSGxrMjMM7L6Qqk7uu0',
#    'summonerName': 'WiIIyrex Fanboy',
#    'leaguePoints': 800,
#    'rank': 'I',
#    'wins': 356,
#    'losses': 315,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ezaeNB0wrxNNVoiA6J7AHE36pOro0cKPimjBpjFk5BLh0TI',
#    'summonerName': 'WD Inter',
#    'leaguePoints': 575,
#    'rank': 'I',
#    'wins': 589,
#    'losses': 556,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '6PTg8vLuqBHJgE-qFVCwgOCHd5sca1EFTJfZk2CxGq52g0Ye',
#    'summonerName': 'sad in head',
#    'leaguePoints': 606,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 162,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'PNI-YpPLmeHtk4AI21nz4A0Q9GApOYuiXXgpw0orR7X86ng',
#    'summonerName': 'never retreat',
#    'leaguePoints': 703,
#    'rank': 'I',
#    'wins': 389,
#    'losses': 358,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'Nz0b934F1K5QWh0878IzL8XdNGD3PLXTfhBCt-yHzToUSmF0',
#    'summonerName': 'tempogood',
#    'leaguePoints': 671,
#    'rank': 'I',
#    'wins': 412,
#    'losses': 365,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'hIyBCAhwZgy8Q01LsA1Lg1zc-qm4Rmeqh844CKwvqY1Phjw',
#    'summonerName': 'Mykeý',
#    'leaguePoints': 578,
#    'rank': 'I',
#    'wins': 619,
#    'losses': 588,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'dbPwv0gOwtYf6doX7tXLg71F98Hr0t6aH6JG0q50xGNCTgvS',
#    'summonerName': 'Thanos ad acc',
#    'leaguePoints': 642,
#    'rank': 'I',
#    'wins': 156,
#    'losses': 137,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oPfuCszr6trRPN7abo0NGMKOO1RhI8V2MUfKvvbiy_8nbIg',
#    'summonerName': 'Kevin Pearson',
#    'leaguePoints': 570,
#    'rank': 'I',
#    'wins': 929,
#    'losses': 899,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'tqknvmBoT8ywF9u8Hx67qGSxKjdkQy0WEozpf7nhDz3IwCY',
#    'summonerName': 'POOPY PANTIES XD',
#    'leaguePoints': 905,
#    'rank': 'I',
#    'wins': 325,
#    'losses': 280,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ehe7r9SO2TX9NNNtS5sTeKc-PwPe4ny5hQ48DVY0Hc_ch4U',
#    'summonerName': 'Seelame v1',
#    'leaguePoints': 693,
#    'rank': 'I',
#    'wins': 262,
#    'losses': 228,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lagJxe_6byaNQ-yupAJr7Pbhs0ZnklLsnPEr4Dib7WZtY3Rkzgne86UHHA',
#    'summonerName': 'Zootopia Plus',
#    'leaguePoints': 831,
#    'rank': 'I',
#    'wins': 395,
#    'losses': 348,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'NFQTuTzP3TeK1BP9m1WTxH4insdzszcLlmdL4IlmR6w8QEqrfHbi1rImUg',
#    'summonerName': 'Shiganshina',
#    'leaguePoints': 749,
#    'rank': 'I',
#    'wins': 366,
#    'losses': 312,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TaIAbVAw8a5h696lqPNd4So1Z4x41nUohDtWQVBaz3Ry0lSyzjQoDW3hdQ',
#    'summonerName': 'DIA LUKA1',
#    'leaguePoints': 798,
#    'rank': 'I',
#    'wins': 384,
#    'losses': 348,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'ENXzNohzqmpoUI3pcBWQfQI3sFgypSSmuASKJdYLwNZBXxs',
#    'summonerName': 'Yaspooky',
#    'leaguePoints': 834,
#    'rank': 'I',
#    'wins': 232,
#    'losses': 187,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BarhYkwad00wVQPaY6gywz5Jvz4kTNc3aqBfnD8vJDjLOgc',
#    'summonerName': 'xumäS',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 403,
#    'losses': 374,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'kQCRCr4iocPd1uG3lHBUHYw35bczYKAfI1KKobWUQtVMBqs',
#    'summonerName': 'Gaunter O Dimm',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 220,
#    'losses': 184,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'HqKnoebgHEzvgASi-HIuoj0WiXgjcmJyXZfCP16MRGDfAtuL-oKXzdAZ8Q',
#    'summonerName': 'jkjkjkjkjkjkk',
#    'leaguePoints': 774,
#    'rank': 'I',
#    'wins': 502,
#    'losses': 456,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '9RE_RwUIc0lpGOeiDYQ_aAHJZUSY5xuNtnAYzieVYarfshQ',
#    'summonerName': 'Youre not my dad',
#    'leaguePoints': 615,
#    'rank': 'I',
#    'wins': 195,
#    'losses': 149,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'WW5sd4Rc1-mxnd8V3evBHN_prv9cxraJv29sad1nW03NzwvTbC61-AuXqw',
#    'summonerName': 'Chance4Win',
#    'leaguePoints': 664,
#    'rank': 'I',
#    'wins': 126,
#    'losses': 98,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '4PsGtMtIs458aGwVnDrQBYhnkII7D7HnmVDYX-A80ZW0XbXK',
#    'summonerName': 'SPLAAAAAAAASH',
#    'leaguePoints': 684,
#    'rank': 'I',
#    'wins': 633,
#    'losses': 608,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Ix55sbEa4SNJl08h9qM3aa_NL0yFbquPBvhBkXvgRpje3ra5uGa4EP4LKg',
#    'summonerName': 'ME Cody Sun',
#    'leaguePoints': 706,
#    'rank': 'I',
#    'wins': 179,
#    'losses': 149,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '_gK44cFB-ZumoqerzQbcZo51hCv4vevMsrJvJZewxbEGW6Q',
#    'summonerName': 'Rulfchen',
#    'leaguePoints': 688,
#    'rank': 'I',
#    'wins': 308,
#    'losses': 269,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'QDsaGI_Cy-0Lhc3kFO72PMqfwfGfabBKzqh4g9_0O9bizlwfpiI1s_eN5A',
#    'summonerName': '78943241',
#    'leaguePoints': 739,
#    'rank': 'I',
#    'wins': 146,
#    'losses': 114,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_WyHdYLIE_-ABmZuKPEFkmqWaIggHDEvQRmznjUBkLYlwt0',
#    'summonerName': 'Jonhy',
#    'leaguePoints': 781,
#    'rank': 'I',
#    'wins': 571,
#    'losses': 527,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'u4T2HGWBY51yjX4vvx_zsqtisH0eNKwNSwWbY-uiVvK2js_a',
#    'summonerName': 'Discord Catfish',
#    'leaguePoints': 685,
#    'rank': 'I',
#    'wins': 129,
#    'losses': 90,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8uE6M8F3y0uknECUAuDmmVxDUQ5B8ZM396ymdECgCTlnxIqX',
#    'summonerName': 'TEST ACC 123321',
#    'leaguePoints': 613,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 130,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Y-nnTd9pdKRpBW6FOrzANe9Evu9e9-b1qrxgkts_sAwtuuD5',
#    'summonerName': 'XWogen',
#    'leaguePoints': 660,
#    'rank': 'I',
#    'wins': 429,
#    'losses': 388,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'kG2hoUx21_R28z7No3XAAHK90QKk9xiF9rIIOcdeVEN02ZE',
#    'summonerName': 'Gabbo',
#    'leaguePoints': 848,
#    'rank': 'I',
#    'wins': 204,
#    'losses': 163,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '-5xgVY4oLaXpjhYIn6Xm4FKF5Msp4j4tYrf9cVYv31UYuyE',
#    'summonerName': '1597351379',
#    'leaguePoints': 603,
#    'rank': 'I',
#    'wins': 370,
#    'losses': 343,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': '0zUX_Er3DGXELIWlNMDVQSiJF1NsYnxtyPvqyo04BFZ-ICh7w2IcR7c8ww',
#    'summonerName': 'Remains of life',
#    'leaguePoints': 608,
#    'rank': 'I',
#    'wins': 303,
#    'losses': 247,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'UPPoAyMU1JkejFd-8nsSZGGD_uxKHOdVA7nekgYrhv2z7VJg',
#    'summonerName': 'RhiIech',
#    'leaguePoints': 658,
#    'rank': 'I',
#    'wins': 382,
#    'losses': 364,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '1hq_AhORwbcktrDioUI8u36TKnO17ECBCIf_bo-oGPw_cR0',
#    'summonerName': 'SAD TunisiaKing',
#    'leaguePoints': 614,
#    'rank': 'I',
#    'wins': 310,
#    'losses': 267,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'K6l_Dxoib3sx1fQbg6IMfKbzshEvwVrJwLZ2pWULNlYceD0',
#    'summonerName': 'JeppeHou',
#    'leaguePoints': 648,
#    'rank': 'I',
#    'wins': 276,
#    'losses': 241,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ogI2ZM9NawJy3BV7Y4pNj7AL_fOeH-dZ9zBck6rO9T7o9bY',
#    'summonerName': 'LFT Goldenpenny',
#    'leaguePoints': 628,
#    'rank': 'I',
#    'wins': 258,
#    'losses': 232,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pO9txIAu8DChsiCaMsNrkaUbhYAca4ikrZysiLb4n48FMrntFigbt9tA5g',
#    'summonerName': 'Thats a shame',
#    'leaguePoints': 746,
#    'rank': 'I',
#    'wins': 140,
#    'losses': 96,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'MJXnXFjdrRjf0dz9dSB_zt_JXRnClKuf8aDPg31I7ldKpwyd',
#    'summonerName': 'LDLC Yike',
#    'leaguePoints': 878,
#    'rank': 'I',
#    'wins': 221,
#    'losses': 182,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'FaM4A4djWmFwhBvO9R7Bl_8dKIojflSwtBHWbGz_Mc2OrGfe',
#    'summonerName': 'MutantGecko11',
#    'leaguePoints': 704,
#    'rank': 'I',
#    'wins': 136,
#    'losses': 133,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '67f8yCzlhrYbOOj45pbRZ7kdd0V6tvDDUgNIfW646qUjjZv8',
#    'summonerName': 'dont talk to me9',
#    'leaguePoints': 622,
#    'rank': 'I',
#    'wins': 168,
#    'losses': 113,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zE8S4yPEtFqowGWP0CAZlX5XnxQIfZ9tIVPAY6_blKIk1K0cHSRgLT8djA',
#    'summonerName': 'KOR BEST ADC',
#    'leaguePoints': 635,
#    'rank': 'I',
#    'wins': 263,
#    'losses': 211,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'qXCpaqxkNfdpudK-pVOsqt3mOlYzdDqEnkXiPM2Z7_3KOcc',
#    'summonerName': 'StenBosse',
#    'leaguePoints': 790,
#    'rank': 'I',
#    'wins': 327,
#    'losses': 289,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '_kPT3aC9E9rFOP0nZSzYH-i7bwzNDRJMubPCLbTQ7zYWXgEu',
#    'summonerName': 'NZNZNZNZNZNZ',
#    'leaguePoints': 774,
#    'rank': 'I',
#    'wins': 423,
#    'losses': 385,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'WJRRZkiyTS1AEy3veRYTxG3MJNdsRFL_s4n0BNg2kakc0g4',
#    'summonerName': 'Mike Wazοwski',
#    'leaguePoints': 640,
#    'rank': 'I',
#    'wins': 81,
#    'losses': 50,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'c9YQvOBheVFjH4hf5jWYl_KaupGc91q9mfDyHjugYt4Zq4ob',
#    'summonerName': 'Scorth',
#    'leaguePoints': 918,
#    'rank': 'I',
#    'wins': 404,
#    'losses': 365,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'hbbUqTPKtQ7-V1zsthh-CdOh29vrqn-WKIs79gab9bUBc3Q',
#    'summonerName': 'sof',
#    'leaguePoints': 788,
#    'rank': 'I',
#    'wins': 216,
#    'losses': 176,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '6_9NwXx5WSa3Fw7Sa7GC1y_3S7nIENXZOn7DsNisSd0Ox0U',
#    'summonerName': 'Jambitøman',
#    'leaguePoints': 611,
#    'rank': 'I',
#    'wins': 407,
#    'losses': 365,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HQ0XHFKGhvvEaodKvvD5p7exU_IOmq_gI7ZVpBYGgctAM3Wp',
#    'summonerName': 'SLQ Buzgej',
#    'leaguePoints': 709,
#    'rank': 'I',
#    'wins': 242,
#    'losses': 200,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'ViNP5BSisDMdwsxYd6ajuR29krVuifd1tMDcp9asPIK5g3M',
#    'summonerName': 'Zac Jones',
#    'leaguePoints': 605,
#    'rank': 'I',
#    'wins': 137,
#    'losses': 111,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'd1BPXSgAM8rjd2X1SHpG8OXXfd6cocScB9QCR0toC-PacL0',
#    'summonerName': 'Skude V2',
#    'leaguePoints': 920,
#    'rank': 'I',
#    'wins': 205,
#    'losses': 155,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'hGZItezQ-5NeNkwBxrWkQo-cNPsGlSMbiM-5VlZsWJqulMs',
#    'summonerName': 'Afrogirl',
#    'leaguePoints': 710,
#    'rank': 'I',
#    'wins': 341,
#    'losses': 310,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '2VzB8qrLe8BLRavYglbDlAnyOyoF3VI46wYn1nQlKvo_Bo8',
#    'summonerName': 'homielander',
#    'leaguePoints': 642,
#    'rank': 'I',
#    'wins': 180,
#    'losses': 155,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5QUV-fAl8SwlKsQ-FFZ-S-El42_pK7mOiVkJVPkRmWLb390T7j99ohrTjw',
#    'summonerName': 'WystrzalowyKap62',
#    'leaguePoints': 633,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'p_tlkf_qpve2YJFuqVQRhzIFjvgaOt6QvVvz1eTquw2mAOI',
#    'summonerName': 'mLaSudaSoyManoIo',
#    'leaguePoints': 612,
#    'rank': 'I',
#    'wins': 306,
#    'losses': 301,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1hyropZYqiz_aRr9yX3h8Xwm0zGBhe-A1LhRnVFM7nB5kZOA',
#    'summonerName': 'Catradora',
#    'leaguePoints': 656,
#    'rank': 'I',
#    'wins': 414,
#    'losses': 382,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'F3Li6nYjixvwMK1duwElOoJou1l4rgpXKWpwp8p_xo9J36UE',
#    'summonerName': 'FRZYY',
#    'leaguePoints': 616,
#    'rank': 'I',
#    'wins': 259,
#    'losses': 235,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-GahjMVgNSF8yFHQghiXK0_AQWWqDlN0HRO9bqBzr2MH25w',
#    'summonerName': 'EL BARDOOOO',
#    'leaguePoints': 721,
#    'rank': 'I',
#    'wins': 441,
#    'losses': 414,
#    'veteran': False,
#    'inactive': False,
# ...
#    'losses': 216,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'bUbZx9__2uLHGA5qe5QiFRIUq7usFX4eb5ZjJcVlECbyOKvK',
#    'summonerName': 'Xeronic',
#    'leaguePoints': 645,
#    'rank': 'I',
#    'wins': 270,
#    'losses': 237,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '44VM7mEoYM61wLFdMI61d-a89MpQ7RLrB9SG0PebrYlJspo',
#    'summonerName': '7 7 7 7',
#    'leaguePoints': 618,
#    'rank': 'I',
#    'wins': 231,
#    'losses': 206,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nWbWBua4AN7sGD1gMAp2dz8G4N-FR191ENRJHpZKJ1PeyW8',
#    'summonerName': 'Mindrago',
#    'leaguePoints': 693,
#    'rank': 'I',
#    'wins': 249,
#    'losses': 200,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'jtBXUW7EMSggDBZhORUw2vRYXJnM-1k-uYk7lU40kWb0qTJb',
#    'summonerName': 'Qomolococ',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 229,
#    'losses': 202,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'JlYBTggAlQxEaDUn9-H0XrSqWAG9oBYGkfBETEKBBfypVzLq-erUfV75iQ',
#    'summonerName': 'RobloxKING4206 9',
#    'leaguePoints': 738,
#    'rank': 'I',
#    'wins': 253,
#    'losses': 219,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'IQAjlxs57q10h-cU_xhTUG2OB1Fu1z2i0KQiHZSrBut4ZAg',
#    'summonerName': 'PSOFO PRODOTH',
#    'leaguePoints': 799,
#    'rank': 'I',
#    'wins': 239,
#    'losses': 191,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'VErCZqRu8s0s_TayUL8nWeCn8ZiXAQTgYzgOcm2bQXjWcssuqbuDtbb3Fg',
#    'summonerName': 'dwox6',
#    'leaguePoints': 698,
#    'rank': 'I',
#    'wins': 135,
#    'losses': 110,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'rKCYWPJCmCOa5dKYTQFr7jLK-d-TXAlgoXXQD4kWJirW2nb5mNwIsjVF5A',
#    'summonerName': 'ADHD Akali',
#    'leaguePoints': 803,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 125,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'oth9ykmqsAesdkFE5cIGf3eCUd8rFM5utKI2R92Bw-ndBVw',
#    'summonerName': 'Tanu',
#    'leaguePoints': 863,
#    'rank': 'I',
#    'wins': 217,
#    'losses': 181,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lLpHKL65n0GZokRPU-ORoKixNhpqt9jEyf9h4MBOGc4qQVg',
#    'summonerName': 'WD towhat',
#    'leaguePoints': 738,
#    'rank': 'I',
#    'wins': 511,
#    'losses': 469,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'kRLmrOA_V1X4HK_w55A83zGfVhBjUHVdJ_DLZ40snmQRYvc',
#    'summonerName': 'Ekko the Neeko',
#    'leaguePoints': 583,
#    'rank': 'I',
#    'wins': 728,
#    'losses': 713,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '7cF2Dvry36eWOtEjN0-07SP3Ysm--UOr33ktyUwhqugiss-oQuY236FfPA',
#    'summonerName': 'Lovelοrn',
#    'leaguePoints': 602,
#    'rank': 'I',
#    'wins': 237,
#    'losses': 219,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'PnO0DDOfmevkNWLVXCk1bxh9jV6x7BVxAy4VTyBX045hXDAU',
#    'summonerName': 'TTV subbexlol',
#    'leaguePoints': 625,
#    'rank': 'I',
#    'wins': 327,
#    'losses': 292,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'qSb6Cw0nWBg683Ek6XZPwrGd82QysXYlgEFIgg33ZLY0HQI',
#    'summonerName': 'MIHAIWALRUS666',
#    'leaguePoints': 673,
#    'rank': 'I',
#    'wins': 560,
#    'losses': 505,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'm7P_oCqWt8_5lsZyGCGqmWP1Iw1_PFT2AMHjeR6rN83QU9-8',
#    'summonerName': 'I Will Perform',
#    'leaguePoints': 672,
#    'rank': 'I',
#    'wins': 649,
#    'losses': 602,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CsEC9r6UODIdAXWMUH6lMuJvbvVh0ryF1WkOrJDo9AKTApY',
#    'summonerName': 'CEO Mikey',
#    'leaguePoints': 680,
#    'rank': 'I',
#    'wins': 427,
#    'losses': 392,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Ya1-YJWJI82cBEIx43kXuWAYq01Rh69VVW2hD5tSJXxdZbYE',
#    'summonerName': 'Hello is me 1',
#    'leaguePoints': 744,
#    'rank': 'I',
#    'wins': 483,
#    'losses': 391,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'gHfgO8lFq1-cY-41LCvczMjysOrA7n0_2vLlnqKcWd67Q1q8',
#    'summonerName': 'ŁαstAckermαη',
#    'leaguePoints': 603,
#    'rank': 'I',
#    'wins': 321,
#    'losses': 287,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'MfnIA5L9-xyK7rvg_9fQTlX7RxNwpmZPmzzDpQHRk3m1l-8',
#    'summonerName': 'indoor fish',
#    'leaguePoints': 732,
#    'rank': 'I',
#    'wins': 189,
#    'losses': 156,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'HkM33p6MwGC2KQkUIu5ON2xZmHsPkIcAwHAEELcqy1hA_T8',
#    'summonerName': 'KC Ηantera',
#    'leaguePoints': 621,
#    'rank': 'I',
#    'wins': 450,
#    'losses': 429,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'h0xzB297x3B2DGHU_7Sf1l0Scncnb0FkYnro76vtT5_DF6PT',
#    'summonerName': 'VselfmadeV',
#    'leaguePoints': 723,
#    'rank': 'I',
#    'wins': 425,
#    'losses': 395,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '8PkVRvuofcPPxodu9P37Nryv9CVTw2qeOLNYiuhtRWw8B5s',
#    'summonerName': 'AD12242',
#    'leaguePoints': 662,
#    'rank': 'I',
#    'wins': 161,
#    'losses': 122,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'I4D8zqF0MsOgQuw70q_j5EmJ0ru-6w1JPWvi6TaVwXxe80Y',
#    'summonerName': 'MADM Gaëthan',
#    'leaguePoints': 808,
#    'rank': 'I',
#    'wins': 527,
#    'losses': 495,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '7sS0hZSn3QGDkOGS6ziGt5hCIiqBC1CUJ7k78h8RVWUDaCg',
#    'summonerName': 'Hiroko Seto',
#    'leaguePoints': 681,
#    'rank': 'I',
#    'wins': 468,
#    'losses': 414,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'uhzT6cSqRWLgLP3c0xCFFkrj_0ECwA0rzF7PYgbrfemqVUA',
#    'summonerName': 'SmurfWithHarambe',
#    'leaguePoints': 683,
#    'rank': 'I',
#    'wins': 219,
#    'losses': 191,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': '0mLU_Eq0ipeiSKdrOa9YkWEHcOM9gd7pKJ1OVjlcPImcG18H-UElvNbQig',
#    'summonerName': 'kojamord',
#    'leaguePoints': 736,
#    'rank': 'I',
#    'wins': 141,
#    'losses': 95,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Gaf9ukBaRlhp9HE3N-JoeaZSHuBpnpFqEv7hYAYnJP942wy8YHiC48e0PA',
#    'summonerName': 'roi dem0n',
#    'leaguePoints': 826,
#    'rank': 'I',
#    'wins': 403,
#    'losses': 368,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '27ZYZuTMr1yBpqrl_50_CKvzjGK-zp0bz5iUVAXGuG2AQRA',
#    'summonerName': 'TWTV KLUCKADELL',
#    'leaguePoints': 832,
#    'rank': 'I',
#    'wins': 315,
#    'losses': 297,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'e8v4H0buTjO9Dwfp3pH9vDQfzNOESdreM7atOWp3S89LZP8',
#    'summonerName': 'xLittle bee',
#    'leaguePoints': 637,
#    'rank': 'I',
#    'wins': 147,
#    'losses': 105,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2vv0gxp2Hviq7eCv3mdX62XiRlsQxoWlP30FfRq-KRUzBXtb',
#    'summonerName': 'bzrp1',
#    'leaguePoints': 674,
#    'rank': 'I',
#    'wins': 230,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'n0oXiz--eA0vevuD0Fq9R_h_bzKJSSNTxPznTKnfpir8MYY',
#    'summonerName': 'Saucer Doom',
#    'leaguePoints': 799,
#    'rank': 'I',
#    'wins': 155,
#    'losses': 127,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'nfRSgEVoAMmKMukhcVnFv0W2-lI0nEdgMsjsFK4V-rDWxLW6HDw2tiM6gg',
#    'summonerName': 'twitchtvlirdaaa',
#    'leaguePoints': 692,
#    'rank': 'I',
#    'wins': 144,
#    'losses': 121,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'u60nYqzV3g2xkpRpG7Q4sRsFTD1q9RuMwAnPyfuJIHjmSFI',
#    'summonerName': 'Johnny Dolphins',
#    'leaguePoints': 783,
#    'rank': 'I',
#    'wins': 120,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'nMK62nkqLjgQYRo96vZDE4t8G8Vyxyyi4C52td1KgarPkuk',
#    'summonerName': 'Asgir',
#    'leaguePoints': 669,
#    'rank': 'I',
#    'wins': 122,
#    'losses': 78,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'pKhc3DcULMrZCTnZ6OF5n4BXoL6bZ6LJ0LAwEkjbSVSxUY4',
#    'summonerName': 'Lucky Number 15',
#    'leaguePoints': 684,
#    'rank': 'I',
#    'wins': 439,
#    'losses': 410,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'qk-kilJ75RDa8R2-kr_6KE4nsLgI4ZJQUJSXjyKXyU0aU-k',
#    'summonerName': 'ProvencalGaulois',
#    'leaguePoints': 616,
#    'rank': 'I',
#    'wins': 182,
#    'losses': 150,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'XJuBqVVZKSlpeF3IT4mjjA6ouTQI0Q6cdhzL2Q2ZUeafD7pZrkLAlYZGFQ',
#    'summonerName': 'Artênes',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 162,
#    'losses': 140,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'b1R4Z41gqMFpPCGfxRgY4_pIZwAnEWO-y_k6CiarWsZw_PI',
#    'summonerName': 'WeiZoR',
#    'leaguePoints': 847,
#    'rank': 'I',
#    'wins': 214,
#    'losses': 174,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'L9z2UG3ZiJ9Ehl5Fht_6AXL1u7_a34HW175PpexFDDRUPonCNsd5wyVBTA',
#    'summonerName': '42314254',
#    'leaguePoints': 776,
#    'rank': 'I',
#    'wins': 118,
#    'losses': 72,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '36NS20LiyVasIHzlAIU4_tgPYlGLTex2XGjqz8XsLBGbrYradn9DYDoKdA',
#    'summonerName': 'TTVlateroviann99',
#    'leaguePoints': 573,
#    'rank': 'I',
#    'wins': 103,
#    'losses': 81,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'CZbGrCyokzwETa15SmtuQ_y3tFQRr0OEIfB2lQeU7Gj4iOM',
#    'summonerName': 'da go lapa6',
#    'leaguePoints': 662,
#    'rank': 'I',
#    'wins': 130,
#    'losses': 112,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'Qh6uJ8EasWpSClZAK-aLn7tCRJb5MqYxGdt0KhxJRwoOpf5T',
#    'summonerName': '3250',
#    'leaguePoints': 815,
#    'rank': 'I',
#    'wins': 123,
#    'losses': 103,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': '1tJy6_s8u3PluzuGYs2bDTAKs7YVWtSwyEjquO3mzph0IGk',
#    'summonerName': 'rylle zz',
#    'leaguePoints': 609,
#    'rank': 'I',
#    'wins': 79,
#    'losses': 76,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'f-wK2e_LV_pk5ClgIlu_7FgWxPh-AcxcFp7baFmbn5jggfo',
#    'summonerName': 'Rightclicker11',
#    'leaguePoints': 751,
#    'rank': 'I',
#    'wins': 153,
#    'losses': 123,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'Cj7GFj0Z2H3ighzkWl8Xd_Ca4WpFH8gFsVCaHe0SPLPi2I4',
#    'summonerName': 'xKenzuke1',
#    'leaguePoints': 776,
#    'rank': 'I',
#    'wins': 241,
#    'losses': 204,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'S12x5936bXfHLHHcL4hUavE9895NIJn-AneKQC3dYzeGnjz2CpNbFN0zXw',
#    'summonerName': 'STAND FOR GOD',
#    'leaguePoints': 607,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'BM7VTAsjSiZzRi_NCvZUNlPFX8wnBp3WwhWeX-Es1J86bYEQaJONIaGiww',
#    'summonerName': 'bard sona janna',
#    'leaguePoints': 781,
#    'rank': 'I',
#    'wins': 194,
#    'losses': 154,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'zBOgnYZFRoDpWu2ge1ItjNV6BF603zDZYtgIW9qo2QF1Z3s',
#    'summonerName': 'JEWZAURUS REX',
#    'leaguePoints': 682,
#    'rank': 'I',
#    'wins': 164,
#    'losses': 135,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '2h2JDSiUQbCA5U04uwbTFR5kzIRhqtIu2cyirPH5-MN5Gl0',
#    'summonerName': 'Manυel',
#    'leaguePoints': 753,
#    'rank': 'I',
#    'wins': 203,
#    'losses': 146,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'D7x9Y0mATocVQUVewceo0E6kkMLqqRCqnFYj9sOZHzxunYk',
#    'summonerName': 'LOSEEVERYMATCHUP',
#    'leaguePoints': 822,
#    'rank': 'I',
#    'wins': 172,
#    'losses': 126,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'mMktTwTZY5T2KTiC4wam737YRHhol_sybQzFolvJ-5b_dyQ0',
#    'summonerName': 'Foutriquet',
#    'leaguePoints': 671,
#    'rank': 'I',
#    'wins': 173,
#    'losses': 148,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'U9r8WCH2YJvH75KPiNFooFbjG_VQipsupzPjEjd35cO7Smw',
#    'summonerName': 'kerberos int acc',
#    'leaguePoints': 857,
#    'rank': 'I',
#    'wins': 247,
#    'losses': 214,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'lIBiYFMRhjBvR3SjlslqKzWexCv1r7n92kjCXDCF97hU031X',
#    'summonerName': 'Classic Taric',
#    'leaguePoints': 808,
#    'rank': 'I',
#    'wins': 143,
#    'losses': 118,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'KZhYhjXdlZCmdRtRRMDd5hhqO7bHKvA_E6RvjPCrOgdJ364',
#    'summonerName': 'nuggets hunter',
#    'leaguePoints': 820,
#    'rank': 'I',
#    'wins': 512,
#    'losses': 468,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'TxinmDhQuCQvzsim4pBai2yXtx5UFgWPZjqys9R9JQMj8RnArJO-nVyTpA',
#    'summonerName': 'Woo Young Woo',
#    'leaguePoints': 770,
#    'rank': 'I',
#    'wins': 134,
#    'losses': 97,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'fHT0n1mvoAZdH_YTfpb2Td0_kmRIspbKCH_uD7tWaBHWRPk',
#    'summonerName': 'AreYouWeak',
#    'leaguePoints': 680,
#    'rank': 'I',
#    'wins': 238,
#    'losses': 213,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '5XvdwUQDnqZG5B310zdI5X-1TMzCRJa4SV48E0dU5Ko4pBT8lsTM7JG3cg',
#    'summonerName': 'job not finished',
#    'leaguePoints': 685,
#    'rank': 'I',
#    'wins': 106,
#    'losses': 86,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '-ippafNCWsjF9Z5YmROx0Rf2bBoQ4OOe3a5rv0Uztrwd2-w',
#    'summonerName': 'TOPOFTHEMORNING',
#    'leaguePoints': 822,
#    'rank': 'I',
#    'wins': 190,
#    'losses': 147,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': '3MLDAmD7ls6jqTk44BmnZUgqulTqTeqcgJHhdnV-Xtn9pcFr',
#    'summonerName': 'Subbex',
#    'leaguePoints': 732,
#    'rank': 'I',
#    'wins': 159,
#    'losses': 137,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False}]}
